# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read in csv file
data0 = pd.read_csv("C:/Users/ethan/OneDrive/Documents/data0.csv", header=0, na_values = 'NA', low_memory = False)
data0.head()
# Out:
#    Unnamed: 0  match_id  point_id time  video_file_number  video_time  \
# 0           1         1         0  NaN                1.0       654.0
# 1           2         1         0  NaN                1.0       654.0
# 2           3         1         0  NaN                1.0       654.0
# 3           4         1         0  NaN                1.0       654.0
# 4           5         1         0  NaN                1.0       654.0
#
#                 code                          team  player_number  \
# 0           *P22>LUp      University of Louisville            NaN
# 1            *z1>LUp      University of Louisville            NaN
# 2           aP08>LUp  Northern Kentucky University            NaN
# 3            az1>LUp  Northern Kentucky University            NaN
# 4  *22SM#~~~69D~~~00      University of Louisville           22.0
#
#      player_name  ...              point_won_by winning_attack  \
# 0            NaN  ...  University of Louisville          False
# ...

# %%
# filter this data to only defensive touches
df = pd.concat([data0[data0.skill == 'Reception'], data0[data0.skill == 'Dig']])
df.head()
# Out:
#     Unnamed: 0  match_id  point_id time  video_file_number  video_time  \
# 5            6         1         0  NaN                1.0       655.0
# 12          13         1         1  NaN                1.0       678.0
# 22          23         1         2  NaN                1.0       705.0
# 33          34         1         3  NaN                1.0       731.0
# 43          44         1         4  NaN                1.0       740.0
#
#                   code                          team  player_number  \
# 5   a03RM=~~~69DW~~00F  Northern Kentucky University            3.0
# 12  a03RM+~~~69DL~~-1F  Northern Kentucky University            3.0
# 22  a03RM+~~~69DM~~-2F  Northern Kentucky University            3.0
# 33  a03RM-~~~67DM~~-3F  Northern Kentucky University            3.0
# 43  *15RM=~~~59DW~~+2F      University of Louisville           15.0
#
#        player_name  ...                  point_won_by winning_attack  \
# ...

# %%
# clean this data
df = df.replace('Gulce Gultekin', 'Gulce Guctekin')
df = df.replace('Maddie Bilinovic', 'Maddy Bilinovic')
df = df.replace('Asjia Oneal', "Asjia O'Neal")
df = df.replace('Bryn Mcgehe', 'Bryn McGehe')
df = df.replace('Hames Nicklin', 'Nicklin Hames')
df = df.replace('Mckenna Vicini', 'McKenna Vicini')
df = df.replace('Melanie Parra Quintero', 'Melanie Parra')

# %%
# manually create dataset of heights and positions
df_hp = pd.DataFrame(np.array([['Abbie Jackson', 72, 'OH'], ['Adanna Rollins', 72, 'OH'], ['Addie VanderWeide', 72, 'OH'],
                               ['Adria Powell', 74, 'OH'], ['Aiko Jones', 74, 'OH'], ['Alexa Hendricks', 67, 'DS'],
                               ['Alexis Dacosta', 71, 'DS'], ['Alexis Shelton', 74, 'OH'], ['Ali Hornung', 70, 'DS'],
                               ['Aliyah Carter', 70, 'OH'], ['Allison Whitten', 66, 'DS'], ['Amaya Tillman', 75, 'MB'],
                               ['Anjelina Starck', 74, 'OH'], ['Anna Debeer', 72, 'OH'], ['Annie Cooke', 71, 'S'],
                               ['Annika Evans', 69, 'S'], ['Annie Benbow', 63, 'DS'], ['Annika Evans', 69, 'S'],
                               ['Aria McComber', 66, 'DS'], ['Ashley Browske', 70, 'DS'], ["Asjia O'Neal", 75, 'MB'],
                               ['Aubrey Hamilton', 74, 'OH'], ['Audrey Nalls', 73, 'OH'], ['Audrey Whitworth', 67, 'DS'],
                               ['Ava Torrance', 61, 'DS'], ['Averi Carlson', 71, 'S'], ['Ayah Elnady', 70, 'OH'],
                               ['Ayden Bartlett', 67, 'DS'], ['Bailey Miller', 75, 'OH'], ['Becca Sakoda', 69, 'DS'],
                               ['Bekka Allick', 76, 'MB'], ["Bella D'Amico", 72, 'S'], ['Bianca Bertolino', 72, 'OH'],
                               ['Breana Edwards', 75, 'OH'], ['Breland Morrissette', 73, 'MB'], ['Brooke Nuneviller', 71, 'OH'],
                               ['Brooke Stonestreet', 70, 'DS'], ['Bryn McGehe', 66, 'DS'], ['Brynn Kirsch', 68, 'DS'],
                               ['Bryshanna Brown', 68, 'DS'], ['Caitie Baird', 75, 'OH'], ['Callie Kemohah', 66, 'DS'],
                               ['Cammy Niesen', 68, 'DS'], ['Camryn Haworth', 70, 'S'], ['Camryn Turner', 68, 'S'],
                               ['Carly Skrabak', 66, 'DS'], ['Caroline Barnes', 71, 'DS'], ['Caroline Bien', 72, 'OH'],
                               ['Caroline Crawford', 75, 'MB'], ['Caroline Stogner', 72, 'OH'], ['Cassie Kuerschen', 69, 'DS'],
                               ['CC McGraw', 71, 'DS'], ['Cecily Bramschreiber', 69, 'DS'], ['Chloe Kaminski', 68, 'DS'],
                               ['Claire Chaussee', 72, 'OH'], ['Connelly Renfrow', 67, 'DS'], ['Courtney Jackson', 68, 'DS'],
                               ['Courtney Jones', 71, 'OH'], ['Danielle Hart', 76, 'MB'], ['Delaney Smith', 68, 'DS'],
                               ['Diana Brown', 72, 'S'], ['Eleanor Beavin', 65, 'DS'], ['Elena Baka', 73, 'OH'],
                               ['Elena Oglivie', 70, 'DS'], ['Elena Scott', 69, 'DS'], ['Elia Rubin', 73, 'OH'],
                               ['Ella Boehle', 69, 'DS'], ['Ella Foti', 72, 'RS'], ['Ella Larkin', 70, 'DS'],
                               ['Ella Rud', 72, 'OH'], ['Ellee Stinson', 62, 'DS'], ['Elli McKissock', 67, 'DS'],
                               ['Emily Brown', 67, 'DS'], ['Emily Canaan', 68, 'DS'], ['Emily Londot', 75, 'OH'],
                               ['Emma Grome', 69, 'S'], ['Emma Halter', 65, 'DS'], ['Erin Lamb', 75, 'OH'],
                               ['Erykah Lovett', 71, 'OH'], ['Eva Hudson', 73, 'OH'], ['Evie Doezema', 75, 'MB'],
                               ['Gabby Blossom', 69, 'S'], ['Gabby Gonzales', 75, 'OH'], ['Gala Trubint', 68, 'DS'],
                               ['Georgia Murphy', 66, 'DS'], ['Gillian Grimes', 67, 'DS'], ['Grace Balensiefer', 70, 'S'],
                               ['Grace Chillingworth', 75, 'OH'], ['Grae Gosnell', 71, 'OH'], ['Gulce Guctekin', 65, 'DS'],
                               ['Hanna Lesiak', 74, 'OH'], ['Hannah Grant', 68, 'DS'], ['Hattie Monson', 66, 'DS'],
                               ['Havyn Gates', 66, 'DS'], ['Isa Lopez', 66, 'DS'], ['Izzy Ashburn', 71, 'S'],
                               ['Jasmine Davis', 73, 'OH'], ['Jenaisya Moore', 72, 'OH'], ['Jenna Reitsma', 71, 'OH'],
                               ['Jenna Wenaas', 73, 'OH'], ['Jenny Wessling', 67, 'DS'], ['Jess Mruzik', 73, 'OH'],
                               ['Jill Bohnet', 64, 'DS'], ['Jill Gillen', 67, 'OH'], ['Julia Adams', 75, 'OH'],
                               ['Julia Bergmann', 77, 'OH'], ['Julia Norville', 68, 'DS'], ['Julia Orzol', 72, 'OH'],
                               ['Julianna Dalton', 77, 'OH'], ['Kami Miner', 72, 'S'], ['Kamry Bailey', 72, 'DS'],
                               ['Karly Basham', 68, 'DS'], ['Karly Berkland', 64, 'DS'], ['Kate Georgiades', 69, 'DS'],
                               ['Kate Grimmer', 72, 'OH'], ['Kate Vinson', 67, 'DS'], ['Katie Lukes', 74, 'OH'],
                               ['Kaylee Cox', 74, 'OH'], ['Kayleigh Hames', 72, 'DS'], ['Keagan Polk', 68, 'DS'],
                               ['Keeley Davis', 73, 'OH'], ['Kelsey Knudsen', 68, 'DS'], ['Kendall Kipp', 77, 'OH'],
                               ['Kendra Wait', 70, 'S'], ['Kendyl Reaugh', 75, 'OH'], ['Kenna Sauer', 73, 'OH'],
                               ['Kennedi Orr', 72, 'S'], ['Kennedy Farris', 67, 'DS'], ['Kennedy Warren', 73, 'OH'], 
                               ['Kenzie Harris', 72, 'OH'], ['Kenzie Knuckles', 69, 'DS'], ['Keonilei Akana', 69, 'DS'],
                               ['Kylie Murr', 66, 'DS'], ['Laura Jansen', 72, 'OH'], ['Lauren Bays', 68, 'DS'],
                               ['Lauren Briseno', 67, 'DS'], ['Lauren Harrison', 72, 'OH'], ['Lauren Myrick', 72, 'OH'],
                               ['Leandra Mangual-Duran', 72, 'OH'], ['Lexi Rodriguez', 65, 'DS'], ['Libby Steinhart', 67, 'DS'],
                               ['Lilly Gunter', 68, 'DS'], ['Lily Tessier', 75, 'S'], ['Lindsay Krause', 76, 'OH'],
                               ['Logan Eggleston', 74, 'OH'], ['Lucia Corsaro', 62, 'DS'], ['Mac Podraza', 74, 'S'],
                               ['Mackenzie Morris', 67, 'DS'], ['Maddy Bilinovic', 67, 'DS'], ['Maddie Schermerhorn', 70, 'DS'],
                               ['Maddy Chinn', 75, 'OH'], ['Madi Allen', 68, 'DS'], ['Madi Kubik', 75, 'OH'],
                               ['Madi Malone', 72, 'OH'], ['Madi Robinson', 70, 'OH'], ['Madisen Skinner', 74, 'OH'],
                               ['Madison Soboleski', 72, 'OH'], ['Mady Saris', 73, 'OH'], ['Madyson Chitty', 65, 'DS'],
                               ['Maggie Huber', 66, 'DS'], ['Mari Hinkle', 69, 'DS'], ['Maya Duckworth', 68, 'OH'],
                               ['Maya Sands', 67, 'DS'], ['McKenna Wucherer', 73, 'OH'], ['McKenna Vicini', 74, 'MB'],
                               ['Megan Miller', 66, 'DS'], ['Megan Renner', 74, 'S'], ['Megan Wilson', 76, 'OH'],
                               ['Melani Shaffmaster', 75, 'S'], ['Melanie Parra', 71, 'OH'], ['Merritt Beason', 75, 'OH'],
                               ['Micah Gryniewicz', 73, 'OH'],['Michelle Urquhart', 72, 'OH'], ['Milan Gomillion', 66, 'DS'],
                               ['Mimi Colyer', 75, 'OH'], ['MJ Hammill', 74, 'S'], ['Molly Schultz', 67, 'DS'],
                               ['Morgan Janda', 70, 'S'], ['Nalani Iosia', 68, 'DS'], ['Natalie Risi', 72, 'OH'],
                               ['Nicklin Hames', 70, 'S'], ['Norah Sis', 73, 'OH'], ['Odyssey Warren', 70, 'OH'],
                               ['Olivia Bennett', 65, 'DS'], ['Paige Flickinger', 69, 'OH'], ['Paola Laborda', 67, 'DS'],
                               ['Paola Pimentel', 66, 'DS'], ['Paula Cerame', 68, 'DS'], ['Peyton Chamberlain', 72, 'S'],
                               ['Pia Timmer', 74, 'OH'], ['Rachel Hickey', 64, 'DS'], ['Rachel Kilkelly', 69, 'DS'],
                               ['Raina Terry', 75, 'OH'], ['Raquel Lazaro', 72, 'S'], ['Raven Colvin', 73, 'MB'],
                               ['Reagan Rutherford', 72, 'OH'], ['Rebekah Williams', 69, 'OH'], ['Riah Walker', 70, 'DS'],
                               ['Riley Patterson', 67, 'DS'], ['Rose Booth', 73, 'OH'], ['Ryan White', 66, 'DS'],
                               ['Rylee Rader', 74, 'MB'], ["Saige Ka'aha'aina-Torres", 72, 'S'], ['Sam Csire', 72, 'OH'],
                               ['Samantha Naber', 67, 'DS'], ['Sanaa Dotson', 72, 'OH'], ['Sarah Franklin', 76, 'OH'],
                               ['Sarah Morbitzer', 66, 'DS'], ['Savannah Davison', 70, 'OH'], ['Seleisa Elisaia', 70, 'S'],
                               ['Shania Cromartie', 69, 'OH'], ['Sky McCune', 67, 'DS'], ['Skye Stokes', 69, 'DS'],
                               ['Sophia Keene', 74, 'OH'], ['Sophie Gregus', 73, 'OH'], ['Sydney Dowler', 72, 'S'],
                               ['Sydney Taylor', 69, 'DS'], ['Tamara Otene', 72, 'OH'], ['Taylor Head', 70, 'OH'],
                               ['Taylor Landfair', 77, 'OH'], ['Taylor Preston', 74, 'OH'], ['Trinity Adams', 69, 'DS'],
                               ['Valeria Vazquez', 73, 'OH'], ['Vanessa Ramirez', 64, 'DS'], ['Victoria Schmer', 64, 'DS'],
                               ['Vivian Light', 73, 'OH'], ['Whitney Lauenstein', 74, 'OH'], ['Yadhira Anchante', 72, 'S'],
                               ['Zoe Fleck', 66, 'DS']]),
                   columns = ['Player', 'Height', 'Position'])
df_hp.head()
# Out:
#               Player Height Position
# 0      Abbie Jackson     72       OH
# 1     Adanna Rollins     72       OH
# 2  Addie VanderWeide     72       OH
# 3       Adria Powell     74       OH
# 4         Aiko Jones     74       OH

# %%
# check this data for tidiniess
df_hp[df_hp.Position == 'DS'].sort_values(by = ['Height'])
#df_hp[df_hp.Position == 'OH'].sort_values(by = ['Height'])
#df_hp[df_hp.Position == 'S'].sort_values(by = ['Height'])
#df_hp[df_hp.Position == 'MB'].sort_values(by = ['Height'])
# Out:
#               Player Height Position
# 24      Ava Torrance     61       DS
# 145    Lucia Corsaro     62       DS
# 70     Ellee Stinson     62       DS
# 16      Annie Benbow     63       DS
# 223  Vanessa Ramirez     64       DS
# ..               ...    ...      ...
# 6     Alexis Dacosta     71       DS
# 46   Caroline Barnes     71       DS
# 51         CC McGraw     71       DS
# 118   Kayleigh Hames     72       DS
# 110     Kamry Bailey     72       DS
#
# [95 rows x 3 columns]

# %%
# create one-number metrics for each player
grouped_data = df.groupby(['player_name', 'team'])

# calculate proportions for each evaluation_code
summary = grouped_data.agg(
    Perfect = ('evaluation_code', lambda x: (x == '#').mean()),
    Good = ('evaluation_code', lambda x: (x == '+').mean()),
    OK = ('evaluation_code', lambda x: (x == '!').mean()),
    PoorA = ('evaluation_code', lambda x: (x == '/').mean()),
    PoorB = ('evaluation_code', lambda x: (x == '-').mean()),
    Error = ('evaluation_code', lambda x: (x == '=').mean()),
    count = ('evaluation_code', 'count')
).reset_index()

# add new columns 'dig_score' and 'in_system'
summary['dig_score'] = 3*summary['Perfect'] + 2*summary['Good'] + 1.5*summary['OK'] + summary['PoorA'] + summary['PoorB']
summary['in_system'] = summary['Perfect'] + summary['Good']

# filter rows where 'count' is greater than or equal to 50
result = summary[summary['count'] >= 50]

# %%
# verify equal length data sets
len(result) == len(df_hp)
# Out:
# True

# %%
result.sort_values(by = 'dig_score', ascending = False).head()
# Out:
#           player_name                            team   Perfect      Good  \
# 568   Julianna Dalton        University of Pittsburgh  0.385965  0.333333
# 897     Melanie Parra   University of Texas at Austin  0.419048  0.304762
# 235      Cammy Niesen       University of Mississippi  0.315068  0.369863
# 1010    Rachel Hickey     University of South Alabama  0.492308  0.138462
# 821        Madi Kubik  University of Nebraska-Lincoln  0.314387  0.367673
#
#             OK     PoorA     PoorB     Error  count  dig_score  in_system
# 568   0.087719  0.000000  0.175439  0.017544     57   2.131579   0.719298
# 897   0.038095  0.038095  0.095238  0.104762    105   2.057143   0.723810
# 235   0.136986  0.000000  0.136986  0.041096     73   2.027397   0.684932
# 1010  0.061538  0.000000  0.169231  0.138462     65   2.015385   0.630769
# 821   0.088810  0.019538  0.143872  0.065719    563   1.975133   0.682060

# %%
# left join the height and position data onto the defensive scores data
scores = result.merge(df_hp, left_on = 'player_name', right_on = 'Player')
scores
# Out:
#             player_name                            team   Perfect      Good  \
# 0         Abbie Jackson           University of Houston  0.330049  0.300493
# 1        Adanna Rollins          University of Kentucky  0.196911  0.312741
# 2     Addie VanderWeide              University of Iowa  0.146067  0.337079
# 3          Adria Powell           Ohio State University  0.354839  0.338710
# 4            Aiko Jones        University of Louisville  0.231481  0.388889
# ..                  ...                             ...       ...       ...
# 224     Victoria Schmer           University of Alabama  0.351852  0.203704
# 225        Vivian Light         Oregon State University  0.166667  0.300000
# 226  Whitney Lauenstein  University of Nebraska-Lincoln  0.363636  0.389610
# 227    Yadhira Anchante            Marquette University  0.040541  0.655405
# 228           Zoe Fleck   University of Texas at Austin  0.344099  0.330435
#
# ...

# %%
# create a linear model predicting dig score and in-system percentage from height
# create one model for all players, and one for only defensive specialists
# adjust for player quality metric? (i.e. team strength)
scores.plot(x = 'Height', y = 'dig_score', kind = 'scatter')
#plt.scatter(x=scores['Height'], y=scores['dig_score'],
            #c=scores['Category'].map({'OH': 'red', 'MB': 'blue', 'S': 'orange', 'DS': 'green'}), marker='o')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='dig_score'>

# %%
# data visualizations:
# scatterplot of dig score vs height and in-system percentage vs height, with position as color
# distribution of women's heights vs volleyball DS heights
